# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '../data/vgsales.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df['Global_Sales'].sort_values(ascending=False).head(10)
# Out:
# 0    82.74
# 1    40.24
# 2    35.82
# 3    33.00
# 4    31.37
# 5    30.26
# 6    30.01
# 7    29.02
# 8    28.62
# 9    28.31
# Name: Global_Sales, dtype: float64

# %%
df_1=df[['Name','Global_Sales']].head(10)

# %%
df_1.plot(kind='bar', legend=False, x='Name', y='Global_Sales')

# %% [markdown]
# # Top 5 VideoGames in Japan

# %%
df_jp = df[['Name', 'JP_Sales']].head()

# %%
df_jp_2 = df_jp.sort_index()

# %%
df_jp_2.plot(kind='bar', legend=False, x = 'Name', y='JP_Sales')

# %%
df_jp_1 = df_jp['JP_Sales'].sort_values(ascending=False)

# %%
df_jp_1.plot(kind='bar', legend=False, x='Name', y='JP_Sales')
